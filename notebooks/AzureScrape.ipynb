# %%
import requests
from bs4 import BeautifulSoup
import os

def scrape_azure_documentation(base_url, output_dir):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    response = requests.get(base_url)
    soup = BeautifulSoup(response.content, 'html.parser')

    # Find all the links to documentation pages
    links = soup.find_all('a', href=True)

    for link in links:
        href = link['href']
        if href.startswith('/en-us/azure/'):
            full_url = f"https://docs.microsoft.com{href}"
            print(full_url)
            scrape_documentation_page(full_url, output_dir)

def scrape_documentation_page(url, output_dir):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    # Extract the page title
    title = soup.find('h1').get_text(strip=True)
    filename = f"{title}.txt"
    filepath = os.path.join(output_dir, filename)

    # Extract the main content of the page
    content = soup.find('main')

    with open(filepath, 'w', encoding='utf-8') as file:
        if content:
            file.write(content.get_text(separator='\n', strip=True))
        else:
            file.write("No content found")

    print(f"Scraped {title}")

if __name__ == "__main__":
    base_url = "https://docs.microsoft.com/en-us/azure/"
    output_dir = "azure_docs"
    scrape_azure_documentation(base_url, output_dir)
# Out:
# https://docs.microsoft.com/en-us/azure/developer/
# Scraped Azure developer documentation
# https://docs.microsoft.com/en-us/azure/architecture/
# Scraped Azure Architecture Center
# https://docs.microsoft.com/en-us/azure/cloud-adoption-framework/
# Scraped Microsoft Cloud Adoption Framework for Azure
# https://docs.microsoft.com/en-us/azure/bot-service/
# Scraped Azure AI Bot Service documentation
# https://docs.microsoft.com/en-us/azure/bot-service/
# Scraped Azure AI Bot Service documentation
# https://docs.microsoft.com/en-us/azure/azure-video-indexer/
# Scraped Learn about Azure AI Video Indexer
# https://docs.microsoft.com/en-us/azure/azure-video-indexer/
# Scraped Learn about Azure AI Video Indexer
# https://docs.microsoft.com/en-us/azure/devops/artifacts/
# Scraped Azure Artifacts documentation
# https://docs.microsoft.com/en-us/azure/devops/artifacts/
# Scraped Azure Artifacts documentation
# https://docs.microsoft.com/en-us/azure/devops/boards/
# Scraped Azure Boards documentation
# https://docs.microsoft.com/en-us/azure/devops/boards/
# Scraped Azure Boards documentation
# https://docs.microsoft.com/en-us/azure/confidential-ledger/
# Scraped Azure confidential ledger
# https://docs.microsoft.com/en-us/azure/confidential-ledger/
# Scraped Azure confidential ledger
# https://docs.microsoft.com/en-us/azure/storage/container-storage/
# Scraped Azure Container Storage documentation
# https://docs.microsoft.com/en-us/azure/storage/container-storage/
# Scraped Azure Container Storage documentation
# https://docs.microsoft.com/en-us/azure/cyclecloud/index
# Scraped Azure CycleCloud Documentation
# https://docs.microsoft.com/en-us/azure/cyclecloud/index
# Scraped Azure CycleCloud Documentation
# https://docs.microsoft.com/en-us/azure/data-explorer
# Scraped Azure Data Explorer documentation
# https://docs.microsoft.com/en-us/azure/data-explorer
# Scraped Azure Data Explorer documentation
# https://docs.microsoft.com/en-us/azure/databricks/
# Scraped Azure Databricks documentation
# https://docs.microsoft.com/en-us/azure/databricks/
# Scraped Azure Databricks documentation
# https://docs.microsoft.com/en-us/azure/devops/
# Scraped Azure DevOps documentation
# https://docs.microsoft.com/en-us/azure/devops/
# Scraped Azure DevOps documentation
# https://docs.microsoft.com/en-us/azure/information-protection/
# Scraped Azure Information Protection (AIP) documentation
# https://docs.microsoft.com/en-us/azure/information-protection/
# Scraped Azure Information Protection (AIP) documentation
# https://docs.microsoft.com/en-us/azure/iot/
# Scraped Azure IoT documentation
# https://docs.microsoft.com/en-us/azure/iot/
# Scraped Azure IoT documentation
# https://docs.microsoft.com/en-us/azure/aks/hybrid/aks-edge-overview
# Scraped AKS Edge Essentials
# https://docs.microsoft.com/en-us/azure/aks/hybrid/aks-edge-overview
# Scraped AKS Edge Essentials
# https://docs.microsoft.com/en-us/azure/lab-services/
# Scraped Azure Lab Services documentation
# https://docs.microsoft.com/en-us/azure/lab-services/
# Scraped Azure Lab Services documentation
# https://docs.microsoft.com/en-us/azure/azure-managed-lustre/
# Scraped Azure Managed Lustre File System documentation
# https://docs.microsoft.com/en-us/azure/azure-managed-lustre/
# Scraped Azure Managed Lustre File System documentation
# https://docs.microsoft.com/en-us/azure/media-services/latest/player-media-players-concept
# Scraped Media players for Media Services
# https://docs.microsoft.com/en-us/azure/media-services/latest/player-media-players-concept
# Scraped Media players for Media Services
# https://docs.microsoft.com/en-us/azure/devops/pipelines/
# Scraped Azure Pipelines documentation
# https://docs.microsoft.com/en-us/azure/devops/pipelines/
# Scraped Azure Pipelines documentation
# https://docs.microsoft.com/en-us/azure/quantum/
# Scraped Azure Quantum documentation (preview)
# https://docs.microsoft.com/en-us/azure/quantum/
# Scraped Azure Quantum documentation (preview)
# https://docs.microsoft.com/en-us/azure/devops/repos/
# Scraped Azure Repos documentation
# https://docs.microsoft.com/en-us/azure/devops/repos/
# Scraped Azure Repos documentation
# https://docs.microsoft.com/en-us/azure/azure-sql/index
# Scraped Azure SQL documentation
# https://docs.microsoft.com/en-us/azure/azure-sql/index
# Scraped Azure SQL documentation
# https://docs.microsoft.com/en-us/azure/azure-sql/database/index
# Scraped Azure SQL Database documentation
# https://docs.microsoft.com/en-us/azure/azure-sql/database/index
# Scraped Azure SQL Database documentation
# https://docs.microsoft.com/en-us/azure/azure-sql/managed-instance/index
# Scraped Azure SQL Managed Instance documentation
# https://docs.microsoft.com/en-us/azure/azure-sql/managed-instance/index
# Scraped Azure SQL Managed Instance documentation
# https://docs.microsoft.com/en-us/azure/devops/test/
# Scraped Azure Test Plans documentation
# https://docs.microsoft.com/en-us/azure/devops/test/
# Scraped Azure Test Plans documentation
# https://docs.microsoft.com/en-us/azure/media-services/latest/drm-content-protection-concept
# Scraped Content protection with dynamic encryption and key delivery
# https://docs.microsoft.com/en-us/azure/media-services/latest/drm-content-protection-concept
# Scraped Content protection with dynamic encryption and key delivery
# https://docs.microsoft.com/en-us/azure/media-services/latest/encode-concept
# Scraped Encoding video and audio with Media Services
# https://docs.microsoft.com/en-us/azure/media-services/latest/encode-concept
# Scraped Encoding video and audio with Media Services
# https://docs.microsoft.com/en-us/azure/developer/github/github-actions
# Scraped What is GitHub Actions for Azure
# https://docs.microsoft.com/en-us/azure/developer/github/github-actions
# Scraped What is GitHub Actions for Azure
# https://docs.microsoft.com/en-us/azure/health-bot/
# Scraped Azure AI Health Bot
# https://docs.microsoft.com/en-us/azure/health-bot/
# Scraped Azure AI Health Bot
# https://docs.microsoft.com/en-us/azure/media-services/latest/stream-live-tutorial-with-api
# Scraped Tutorial: Stream live with Media Services by using .NET 7.0
# https://docs.microsoft.com/en-us/azure/media-services/latest/stream-live-tutorial-with-api
# Scraped Tutorial: Stream live with Media Services by using .NET 7.0
# https://docs.microsoft.com/en-us/azure/media-services/latest/
# Scraped Azure Media Services (v3) documentation
# https://docs.microsoft.com/en-us/azure/media-services/latest/
# Scraped Azure Media Services (v3) documentation
# https://docs.microsoft.com/en-us/azure/copilot
# Scraped Microsoft Copilot in Azure (preview) documentation
# https://docs.microsoft.com/en-us/azure/copilot
# Scraped Microsoft Copilot in Azure (preview) documentation
# https://docs.microsoft.com/en-us/azure/azure-sql/virtual-machines/windows/sql-server-on-azure-vm-iaas-what-is-overview?toc=/azure/virtual-machines/windows/toc.json
# Scraped What is SQL Server on Windows Azure Virtual Machines?
# https://docs.microsoft.com/en-us/azure/azure-sql/virtual-machines/windows/sql-server-on-azure-vm-iaas-what-is-overview?toc=/azure/virtual-machines/windows/toc.json
# Scraped What is SQL Server on Windows Azure Virtual Machines?
# https://docs.microsoft.com/en-us/azure/bot-service/
# Scraped Azure AI Bot Service documentation
# https://docs.microsoft.com/en-us/azure/azure-video-indexer/
# Scraped Learn about Azure AI Video Indexer
# https://docs.microsoft.com/en-us/azure/databricks/
# Scraped Azure Databricks documentation
# https://docs.microsoft.com/en-us/azure/health-bot/
# Scraped Azure AI Health Bot
# https://docs.microsoft.com/en-us/azure/data-explorer
# Scraped Azure Data Explorer documentation
# https://docs.microsoft.com/en-us/azure/databricks/
# Scraped Azure Databricks documentation
# https://docs.microsoft.com/en-us/azure/cyclecloud/index
# Scraped Azure CycleCloud Documentation
# https://docs.microsoft.com/en-us/azure/quantum/
# Scraped Azure Quantum documentation (preview)
# https://docs.microsoft.com/en-us/azure/azure-sql/virtual-machines/windows/sql-server-on-azure-vm-iaas-what-is-overview?toc=/azure/virtual-machines/windows/toc.json
# Scraped What is SQL Server on Windows Azure Virtual Machines?
# https://docs.microsoft.com/en-us/azure/storage/container-storage/
# Scraped Azure Container Storage documentation
# https://docs.microsoft.com/en-us/azure/confidential-ledger/
# Scraped Azure confidential ledger
# https://docs.microsoft.com/en-us/azure/azure-sql/index
# Scraped Azure SQL documentation
# https://docs.microsoft.com/en-us/azure/azure-sql/database/index
# Scraped Azure SQL Database documentation
# https://docs.microsoft.com/en-us/azure/azure-sql/managed-instance/index
# Scraped Azure SQL Managed Instance documentation
# https://docs.microsoft.com/en-us/azure/azure-sql/virtual-machines/windows/sql-server-on-azure-vm-iaas-what-is-overview?toc=/azure/virtual-machines/windows/toc.json
# Scraped What is SQL Server on Windows Azure Virtual Machines?
# https://docs.microsoft.com/en-us/azure/devops/
# Scraped Azure DevOps documentation
# https://docs.microsoft.com/en-us/azure/devops/pipelines/
# Scraped Azure Pipelines documentation
# https://docs.microsoft.com/en-us/azure/developer/github/github-actions
# Scraped What is GitHub Actions for Azure
# https://docs.microsoft.com/en-us/azure/devops/artifacts/
# Scraped Azure Artifacts documentation
# https://docs.microsoft.com/en-us/azure/devops/boards/
# Scraped Azure Boards documentation
# https://docs.microsoft.com/en-us/azure/devops/
# Scraped Azure DevOps documentation
# https://docs.microsoft.com/en-us/azure/devops/pipelines/
# Scraped Azure Pipelines documentation
# https://docs.microsoft.com/en-us/azure/devops/repos/
# Scraped Azure Repos documentation
# https://docs.microsoft.com/en-us/azure/devops/test/
# Scraped Azure Test Plans documentation
# https://docs.microsoft.com/en-us/azure/developer/github/github-actions
# Scraped What is GitHub Actions for Azure
# https://docs.microsoft.com/en-us/azure/devops/
# Scraped Azure DevOps documentation
# https://docs.microsoft.com/en-us/azure/aks/hybrid/aks-edge-overview
# Scraped AKS Edge Essentials
# https://docs.microsoft.com/en-us/azure/azure-sql/index
# Scraped Azure SQL documentation
# https://docs.microsoft.com/en-us/azure/information-protection/
# Scraped Azure Information Protection (AIP) documentation
# https://docs.microsoft.com/en-us/azure/iot/
# Scraped Azure IoT documentation
# https://docs.microsoft.com/en-us/azure/copilot
# Scraped Microsoft Copilot in Azure (preview) documentation
# https://docs.microsoft.com/en-us/azure/azure-video-indexer/
# Scraped Learn about Azure AI Video Indexer
# https://docs.microsoft.com/en-us/azure/media-services/latest/player-media-players-concept
# Scraped Media players for Media Services
# https://docs.microsoft.com/en-us/azure/media-services/latest/drm-content-protection-concept
# Scraped Content protection with dynamic encryption and key delivery
# https://docs.microsoft.com/en-us/azure/media-services/latest/encode-concept
# Scraped Encoding video and audio with Media Services
# https://docs.microsoft.com/en-us/azure/media-services/latest/stream-live-tutorial-with-api
# Scraped Tutorial: Stream live with Media Services by using .NET 7.0
# https://docs.microsoft.com/en-us/azure/media-services/latest/
# Scraped Azure Media Services (v3) documentation
# https://docs.microsoft.com/en-us/azure/confidential-ledger/
# Scraped Azure confidential ledger
# https://docs.microsoft.com/en-us/azure/information-protection/
# Scraped Azure Information Protection (AIP) documentation
# https://docs.microsoft.com/en-us/azure/confidential-ledger/
# Scraped Azure confidential ledger
# https://docs.microsoft.com/en-us/azure/storage/container-storage/
# Scraped Azure Container Storage documentation
# https://docs.microsoft.com/en-us/azure/azure-managed-lustre/
# Scraped Azure Managed Lustre File System documentation
# https://docs.microsoft.com/en-us/azure/lab-services/
# Scraped Azure Lab Services documentation
# https://docs.microsoft.com/en-us/azure/developer/python/
# Scraped Azure for Python Developers
# https://docs.microsoft.com/en-us/azure/developer/javascript/
# Scraped Azure for JavaScript & Node.js developers
# https://docs.microsoft.com/en-us/azure/developer/java/
# Scraped Azure for Java developer documentation
# https://docs.microsoft.com/en-us/azure/developer/go/
# Scraped Azure for Go developers
# https://docs.microsoft.com/en-us/azure/developer/jenkins
# Scraped Jenkins on Azure documentation
# https://docs.microsoft.com/en-us/azure/developer/terraform/
# Scraped Terraform on Azure documentation
# https://docs.microsoft.com/en-us/azure/china/
# Scraped Azure in China Playbook

# %%
# !git clone https://github.com/MicrosoftDocs/azure-docs.git
# Out:
# Cloning into 'azure-docs'...
# remote: Enumerating objects: 7448541, done.
# remote: Counting objects: 100% (5592/5592), done.
# remote: Compressing objects: 100% (1908/1908), done.
# remote: Total 7448541 (delta 3697), reused 5427 (delta 3639), pack-reused 7442949
# Receiving objects: 100% (7448541/7448541), 22.78 GiB | 20.10 MiB/s, done.
# Resolving deltas: 100% (5776890/5776890), done.
# Updating files: 100% (82435/82435), done.

# %%
import json
import datetime
import time
import urllib 

from azure.core.exceptions import AzureError
from azure.core.credentials import AzureKeyCredential
import pymongo

from openai import AzureOpenAI
from dotenv import load_dotenv
import os

# %%
load_dotenv()
COSMOS_MONGO_USER = os.getenv("COSMOS_MONGO_USER")
COSMOS_MONGO_PWD = os.getenv("COSMOS_MONGO_PWD")
COSMOS_MONGO_SERVER = os.getenv("COSMOS_MONGO_SERVER")

AOAI_client = AzureOpenAI(api_key=os.getenv("AZURE_OPENAI_KEY"), azure_endpoint=os.getenv("AZURE_OPENAI_ENDPOINT"), api_version="2024-02-01",)

# %%
# import os
import time
# import openai
import pymongo
from bson import ObjectId

# Initialize Azure OpenAI client
# openai.api_key = 'your_openai_api_key'

# Initialize MongoDB client
mongo_conn = "mongodb+srv://"+urllib.parse.quote(COSMOS_MONGO_USER)+":"+urllib.parse.quote(COSMOS_MONGO_PWD)+"@"+COSMOS_MONGO_SERVER
client = pymongo.MongoClient(mongo_conn)

db = client['azure']
collection = db['azure_collection']

def generate_embeddings(text):
    '''
    Generate embeddings from a string of text.
    This will be used to vectorize data and user input for interactions with Azure OpenAI.
    '''

#     response = AOAI_client.embeddings.create(
#     input = "The name of the person is surya. he has various skills in azure, openai, machine learning.",
#     model= "text-embedding-ada-002"
# )
    response = AOAI_client.embeddings.create(input=text, model="text-embedding-ada-002")
    response = response.model_dump()
    embeddings = response['data'][0]['embedding']
    time.sleep(0.5)  # To avoid hitting rate limits
    return embeddings

def process_file(file_path, doc_id):
    with open(file_path, 'r', encoding='utf-8') as file:
        content = file.read()
    
    # Optional: Split content into chunks if it's too large
    chunks = [content[i:i + 4000] for i in range(0, len(content), 4000)]
    
    for idx, chunk in enumerate(chunks):
        embedding = generate_embeddings(chunk)
        document = {
            "id": str(ObjectId()),  # Unique ID for MongoDB document
            "title": os.path.basename(file_path),
            "content": chunk,
            "c_vector": embedding,
            "doc_id": doc_id,
            "chunk_id": idx
        }
        collection.insert_one(document)
        print(f"Inserted chunk {idx} of {file_path}")

def process_directory(directory_path):
    doc_id = 0  # Unique document ID for tracking chunks of the same file
    for root, dirs, files in os.walk(directory_path):
        for file in files:
            if file.endswith('.md'):  # Adjust the file type if needed
                file_path = os.path.join(root, file)
                process_file(file_path, doc_id)
                doc_id += 1

if __name__ == "__main__":
    articles_dir = "./azure-docs/articles"
    process_directory(articles_dir)
# Out:
# /var/folders/9w/58ml_m490y304l00j5v7xblm0000gn/T/ipykernel_6885/1165526520.py:12: UserWarning: You appear to be connected to a CosmosDB cluster. For more information regarding feature compatibility and support please visit https://www.mongodb.com/supportability/cosmosdb
#   client = pymongo.MongoClient(mongo_conn)
# Inserted chunk 0 of ./azure-docs/articles/azure-glossary-cloud-terminology.md
# Inserted chunk 1 of ./azure-docs/articles/azure-glossary-cloud-terminology.md
# Inserted chunk 2 of ./azure-docs/articles/azure-glossary-cloud-terminology.md
# Inserted chunk 3 of ./azure-docs/articles/azure-glossary-cloud-terminology.md
# Inserted chunk 0 of ./azure-docs/articles/third-party-notices.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/set-up-sso.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/set-up-sso.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/eiot-defender-for-endpoint.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/eiot-defender-for-endpoint.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/release-notes-archive.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/release-notes-archive.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/release-notes-archive.md
# Inserted chunk 3 of ./azure-docs/articles/defender-for-iot/organizations/release-notes-archive.md
# Inserted chunk 4 of ./azure-docs/articles/defender-for-iot/organizations/release-notes-archive.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/how-to-set-up-snmp-mib-monitoring.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/how-to-set-up-snmp-mib-monitoring.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/how-to-set-up-snmp-mib-monitoring.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/architecture.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/architecture.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/architecture.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/overview.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/overview.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/faqs-general.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/release-notes.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/release-notes.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/release-notes.md
# Inserted chunk 3 of ./azure-docs/articles/defender-for-iot/organizations/release-notes.md
# Inserted chunk 4 of ./azure-docs/articles/defender-for-iot/organizations/release-notes.md
# Inserted chunk 5 of ./azure-docs/articles/defender-for-iot/organizations/release-notes.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/iot-advanced-threat-monitoring.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/iot-advanced-threat-monitoring.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/iot-advanced-threat-monitoring.md
# Inserted chunk 3 of ./azure-docs/articles/defender-for-iot/organizations/iot-advanced-threat-monitoring.md
# Inserted chunk 4 of ./azure-docs/articles/defender-for-iot/organizations/iot-advanced-threat-monitoring.md
# Inserted chunk 5 of ./azure-docs/articles/defender-for-iot/organizations/iot-advanced-threat-monitoring.md
# Inserted chunk 6 of ./azure-docs/articles/defender-for-iot/organizations/iot-advanced-threat-monitoring.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/how-to-manage-subscriptions.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/how-to-manage-subscriptions.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/how-to-manage-subscriptions.md
# Inserted chunk 3 of ./azure-docs/articles/defender-for-iot/organizations/how-to-manage-subscriptions.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/how-to-create-risk-assessment-reports.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/how-to-create-risk-assessment-reports.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/configure-windows-endpoint-monitoring.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/configure-windows-endpoint-monitoring.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/configure-windows-endpoint-monitoring.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/monitor-zero-trust.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/monitor-zero-trust.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/monitor-zero-trust.md
# Inserted chunk 3 of ./azure-docs/articles/defender-for-iot/organizations/monitor-zero-trust.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/roles-on-premises.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/roles-on-premises.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/roles-on-premises.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/manage-subscriptions-enterprise.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/manage-subscriptions-enterprise.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/manage-subscriptions-enterprise.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/how-to-investigate-sensor-detections-in-a-device-inventory.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/how-to-investigate-sensor-detections-in-a-device-inventory.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/how-to-investigate-sensor-detections-in-a-device-inventory.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/how-to-troubleshoot-sensor.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/how-to-troubleshoot-sensor.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/how-to-troubleshoot-sensor.md
# Inserted chunk 3 of ./azure-docs/articles/defender-for-iot/organizations/how-to-troubleshoot-sensor.md
# Inserted chunk 4 of ./azure-docs/articles/defender-for-iot/organizations/how-to-troubleshoot-sensor.md
# Inserted chunk 5 of ./azure-docs/articles/defender-for-iot/organizations/how-to-troubleshoot-sensor.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/how-to-manage-sensors-on-the-cloud.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/how-to-manage-sensors-on-the-cloud.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/how-to-manage-sensors-on-the-cloud.md
# Inserted chunk 3 of ./azure-docs/articles/defender-for-iot/organizations/how-to-manage-sensors-on-the-cloud.md
# Inserted chunk 4 of ./azure-docs/articles/defender-for-iot/organizations/how-to-manage-sensors-on-the-cloud.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/architecture-connections.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/architecture-connections.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/ot-appliance-sizing.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/ot-appliance-sizing.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/connect-sensors.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/connect-sensors.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/connect-sensors.md
# Inserted chunk 3 of ./azure-docs/articles/defender-for-iot/organizations/connect-sensors.md
# Inserted chunk 4 of ./azure-docs/articles/defender-for-iot/organizations/connect-sensors.md
# Inserted chunk 5 of ./azure-docs/articles/defender-for-iot/organizations/connect-sensors.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/ot-virtual-appliances.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/ot-virtual-appliances.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/references-data-retention.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/references-data-retention.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/references-data-retention.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/tutorial-forescout.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/tutorial-forescout.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/tutorial-forescout.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/how-to-create-data-mining-queries.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/how-to-create-data-mining-queries.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/how-to-forward-alert-information-to-partners.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/how-to-forward-alert-information-to-partners.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/how-to-forward-alert-information-to-partners.md
# Inserted chunk 3 of ./azure-docs/articles/defender-for-iot/organizations/how-to-forward-alert-information-to-partners.md
# Inserted chunk 4 of ./azure-docs/articles/defender-for-iot/organizations/how-to-forward-alert-information-to-partners.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/tutorial-splunk.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/tutorial-splunk.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/concept-supported-protocols.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/concept-supported-protocols.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/how-to-create-attack-vector-reports.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/how-to-create-attack-vector-reports.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/how-to-manage-individual-sensors.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/how-to-manage-individual-sensors.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/how-to-manage-individual-sensors.md
# Inserted chunk 3 of ./azure-docs/articles/defender-for-iot/organizations/how-to-manage-individual-sensors.md
# Inserted chunk 4 of ./azure-docs/articles/defender-for-iot/organizations/how-to-manage-individual-sensors.md
# Inserted chunk 5 of ./azure-docs/articles/defender-for-iot/organizations/how-to-manage-individual-sensors.md
# Inserted chunk 6 of ./azure-docs/articles/defender-for-iot/organizations/how-to-manage-individual-sensors.md
# Inserted chunk 7 of ./azure-docs/articles/defender-for-iot/organizations/how-to-manage-individual-sensors.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/extra-deploy-enterprise-iot.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/extra-deploy-enterprise-iot.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/getting-started.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/getting-started.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/billing.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/device-inventory.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/device-inventory.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/device-inventory.md
# Inserted chunk 3 of ./azure-docs/articles/defender-for-iot/organizations/device-inventory.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/respond-ot-alert.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/respond-ot-alert.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/respond-ot-alert.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/how-to-manage-device-inventory-for-organizations.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/how-to-manage-device-inventory-for-organizations.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/how-to-manage-device-inventory-for-organizations.md
# Inserted chunk 3 of ./azure-docs/articles/defender-for-iot/organizations/how-to-manage-device-inventory-for-organizations.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/tutorial-servicenow.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/tutorial-servicenow.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/track-user-activity.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/track-user-activity.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/references-work-with-defender-for-iot-cli-commands.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/references-work-with-defender-for-iot-cli-commands.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/references-work-with-defender-for-iot-cli-commands.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/configure-reverse-dns-lookup.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/custom-columns-sample-script.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/custom-columns-sample-script.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/manage-users-sensor.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/manage-users-sensor.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/manage-users-sensor.md
# Inserted chunk 3 of ./azure-docs/articles/defender-for-iot/organizations/manage-users-sensor.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/whats-new.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/whats-new.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/whats-new.md
# Inserted chunk 3 of ./azure-docs/articles/defender-for-iot/organizations/whats-new.md
# Inserted chunk 4 of ./azure-docs/articles/defender-for-iot/organizations/whats-new.md
# Inserted chunk 5 of ./azure-docs/articles/defender-for-iot/organizations/whats-new.md
# Inserted chunk 6 of ./azure-docs/articles/defender-for-iot/organizations/whats-new.md
# Inserted chunk 7 of ./azure-docs/articles/defender-for-iot/organizations/whats-new.md
# Inserted chunk 8 of ./azure-docs/articles/defender-for-iot/organizations/whats-new.md
# Inserted chunk 9 of ./azure-docs/articles/defender-for-iot/organizations/whats-new.md
# Inserted chunk 10 of ./azure-docs/articles/defender-for-iot/organizations/whats-new.md
# Inserted chunk 11 of ./azure-docs/articles/defender-for-iot/organizations/whats-new.md
# Inserted chunk 12 of ./azure-docs/articles/defender-for-iot/organizations/whats-new.md
# Inserted chunk 13 of ./azure-docs/articles/defender-for-iot/organizations/whats-new.md
# Inserted chunk 14 of ./azure-docs/articles/defender-for-iot/organizations/whats-new.md
# Inserted chunk 15 of ./azure-docs/articles/defender-for-iot/organizations/whats-new.md
# Inserted chunk 16 of ./azure-docs/articles/defender-for-iot/organizations/whats-new.md
# Inserted chunk 17 of ./azure-docs/articles/defender-for-iot/organizations/whats-new.md
# Inserted chunk 18 of ./azure-docs/articles/defender-for-iot/organizations/whats-new.md
# Inserted chunk 19 of ./azure-docs/articles/defender-for-iot/organizations/whats-new.md
# Inserted chunk 20 of ./azure-docs/articles/defender-for-iot/organizations/whats-new.md
# Inserted chunk 21 of ./azure-docs/articles/defender-for-iot/organizations/whats-new.md
# Inserted chunk 22 of ./azure-docs/articles/defender-for-iot/organizations/whats-new.md
# Inserted chunk 23 of ./azure-docs/articles/defender-for-iot/organizations/whats-new.md
# Inserted chunk 24 of ./azure-docs/articles/defender-for-iot/organizations/whats-new.md
# Inserted chunk 25 of ./azure-docs/articles/defender-for-iot/organizations/whats-new.md
# Inserted chunk 26 of ./azure-docs/articles/defender-for-iot/organizations/whats-new.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/compliance.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/release-notes-sentinel.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/release-notes-sentinel.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/how-to-control-what-traffic-is-monitored.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/how-to-control-what-traffic-is-monitored.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/how-to-control-what-traffic-is-monitored.md
# Inserted chunk 3 of ./azure-docs/articles/defender-for-iot/organizations/how-to-control-what-traffic-is-monitored.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/iot-solution.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/iot-solution.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/iot-solution.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/tutorial-clearpass.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/tutorial-clearpass.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/tutorial-clearpass.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/manage-users-portal.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/manage-users-portal.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/how-to-create-trends-and-statistics-reports.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/how-to-create-trends-and-statistics-reports.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/alerts.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/alerts.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/alerts.md
# Inserted chunk 3 of ./azure-docs/articles/defender-for-iot/organizations/alerts.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/tutorial-fortinet.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/tutorial-fortinet.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/tutorial-fortinet.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/onboard-sensors.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/onboard-sensors.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/how-to-analyze-programming-details-changes.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/how-to-analyze-programming-details-changes.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/how-to-work-with-threat-intelligence-packages.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/how-to-work-with-threat-intelligence-packages.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/how-to-work-with-threat-intelligence-packages.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/detect-windows-endpoints-script.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/detect-windows-endpoints-script.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/manage-users-overview.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/manage-users-overview.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/configure-active-monitoring.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/how-to-import-device-information.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/how-to-import-device-information.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/update-ot-software.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/update-ot-software.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/update-ot-software.md
# Inserted chunk 3 of ./azure-docs/articles/defender-for-iot/organizations/update-ot-software.md
# Inserted chunk 4 of ./azure-docs/articles/defender-for-iot/organizations/update-ot-software.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/tutorial-palo-alto.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/tutorial-palo-alto.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/tutorial-palo-alto.md
# Inserted chunk 3 of ./azure-docs/articles/defender-for-iot/organizations/tutorial-palo-alto.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/ot-pre-configured-appliances.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/ot-pre-configured-appliances.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/ot-pre-configured-appliances.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/networking-requirements.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/networking-requirements.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/cli-ot-sensor.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/cli-ot-sensor.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/cli-ot-sensor.md
# Inserted chunk 3 of ./azure-docs/articles/defender-for-iot/organizations/cli-ot-sensor.md
# Inserted chunk 4 of ./azure-docs/articles/defender-for-iot/organizations/cli-ot-sensor.md
# Inserted chunk 5 of ./azure-docs/articles/defender-for-iot/organizations/cli-ot-sensor.md
# Inserted chunk 6 of ./azure-docs/articles/defender-for-iot/organizations/cli-ot-sensor.md
# Inserted chunk 7 of ./azure-docs/articles/defender-for-iot/organizations/cli-ot-sensor.md
# Inserted chunk 8 of ./azure-docs/articles/defender-for-iot/organizations/cli-ot-sensor.md
# Inserted chunk 9 of ./azure-docs/articles/defender-for-iot/organizations/cli-ot-sensor.md
# Inserted chunk 10 of ./azure-docs/articles/defender-for-iot/organizations/cli-ot-sensor.md
# Inserted chunk 11 of ./azure-docs/articles/defender-for-iot/organizations/cli-ot-sensor.md
# Inserted chunk 12 of ./azure-docs/articles/defender-for-iot/organizations/cli-ot-sensor.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/sensor-health-messages.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/concept-enterprise.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/concept-enterprise.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/how-to-work-with-the-sensor-device-map.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/how-to-work-with-the-sensor-device-map.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/how-to-work-with-the-sensor-device-map.md
# Inserted chunk 3 of ./azure-docs/articles/defender-for-iot/organizations/how-to-work-with-the-sensor-device-map.md
# Inserted chunk 4 of ./azure-docs/articles/defender-for-iot/organizations/how-to-work-with-the-sensor-device-map.md
# Inserted chunk 5 of ./azure-docs/articles/defender-for-iot/organizations/how-to-work-with-the-sensor-device-map.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/how-to-manage-cloud-alerts.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/how-to-manage-cloud-alerts.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/how-to-manage-cloud-alerts.md
# Inserted chunk 3 of ./azure-docs/articles/defender-for-iot/organizations/how-to-manage-cloud-alerts.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/integrate-overview.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/integrate-overview.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/integrate-overview.md
# Inserted chunk 3 of ./azure-docs/articles/defender-for-iot/organizations/integrate-overview.md
# Inserted chunk 4 of ./azure-docs/articles/defender-for-iot/organizations/integrate-overview.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/tutorial-cyberark.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/tutorial-cyberark.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/eiot-sensor.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/eiot-sensor.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/eiot-sensor.md
# Inserted chunk 3 of ./azure-docs/articles/defender-for-iot/organizations/eiot-sensor.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/back-up-restore-sensor.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/back-up-restore-sensor.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/alert-engine-messages.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/alert-engine-messages.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/alert-engine-messages.md
# Inserted chunk 3 of ./azure-docs/articles/defender-for-iot/organizations/alert-engine-messages.md
# Inserted chunk 4 of ./azure-docs/articles/defender-for-iot/organizations/alert-engine-messages.md
# Inserted chunk 5 of ./azure-docs/articles/defender-for-iot/organizations/alert-engine-messages.md
# Inserted chunk 6 of ./azure-docs/articles/defender-for-iot/organizations/alert-engine-messages.md
# Inserted chunk 7 of ./azure-docs/articles/defender-for-iot/organizations/alert-engine-messages.md
# Inserted chunk 8 of ./azure-docs/articles/defender-for-iot/organizations/alert-engine-messages.md
# Inserted chunk 9 of ./azure-docs/articles/defender-for-iot/organizations/alert-engine-messages.md
# Inserted chunk 10 of ./azure-docs/articles/defender-for-iot/organizations/alert-engine-messages.md
# Inserted chunk 11 of ./azure-docs/articles/defender-for-iot/organizations/alert-engine-messages.md
# Inserted chunk 12 of ./azure-docs/articles/defender-for-iot/organizations/alert-engine-messages.md
# Inserted chunk 13 of ./azure-docs/articles/defender-for-iot/organizations/alert-engine-messages.md
# Inserted chunk 14 of ./azure-docs/articles/defender-for-iot/organizations/alert-engine-messages.md
# Inserted chunk 15 of ./azure-docs/articles/defender-for-iot/organizations/alert-engine-messages.md
# Inserted chunk 16 of ./azure-docs/articles/defender-for-iot/organizations/alert-engine-messages.md
# Inserted chunk 17 of ./azure-docs/articles/defender-for-iot/organizations/alert-engine-messages.md
# Inserted chunk 18 of ./azure-docs/articles/defender-for-iot/organizations/alert-engine-messages.md
# Inserted chunk 19 of ./azure-docs/articles/defender-for-iot/organizations/alert-engine-messages.md
# Inserted chunk 20 of ./azure-docs/articles/defender-for-iot/organizations/alert-engine-messages.md
# Inserted chunk 21 of ./azure-docs/articles/defender-for-iot/organizations/alert-engine-messages.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/tutorial-qradar.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/tutorial-qradar.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/concept-sentinel-integration.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/concept-sentinel-integration.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/concept-sentinel-integration.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/how-to-accelerate-alert-incident-response.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/how-to-accelerate-alert-incident-response.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/how-to-accelerate-alert-incident-response.md
# Inserted chunk 3 of ./azure-docs/articles/defender-for-iot/organizations/how-to-accelerate-alert-incident-response.md
# Inserted chunk 4 of ./azure-docs/articles/defender-for-iot/organizations/how-to-accelerate-alert-incident-response.md
# Inserted chunk 5 of ./azure-docs/articles/defender-for-iot/organizations/how-to-accelerate-alert-incident-response.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/configure-sensor-settings-portal.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/configure-sensor-settings-portal.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/configure-sensor-settings-portal.md
# Inserted chunk 3 of ./azure-docs/articles/defender-for-iot/organizations/configure-sensor-settings-portal.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/references-work-with-defender-for-iot-apis.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/references-work-with-defender-for-iot-apis.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/how-to-view-alerts.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/how-to-view-alerts.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/how-to-view-alerts.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/how-to-track-sensor-activity.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/how-to-track-sensor-activity.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/workbooks.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/workbooks.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/workbooks.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/recommendations.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/recommendations.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/recommendations.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/tutorial-onboarding.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/tutorial-onboarding.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/tutorial-onboarding.md
# Inserted chunk 3 of ./azure-docs/articles/defender-for-iot/organizations/tutorial-onboarding.md
# Inserted chunk 4 of ./azure-docs/articles/defender-for-iot/organizations/tutorial-onboarding.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/roles-azure.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/roles-azure.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/concept-zero-trust.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/concept-zero-trust.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/ot-deploy/update-device-inventory.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/ot-deploy/update-device-inventory.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/ot-deploy/create-learned-baseline.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/ot-deploy/create-learned-baseline.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/ot-deploy/post-install-validation-ot-software.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/ot-deploy/post-install-validation-ot-software.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/ot-deploy/install-software-ot-sensor.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/ot-deploy/install-software-ot-sensor.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/ot-deploy/install-software-ot-sensor.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/ot-deploy/provision-cloud-management.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/ot-deploy/create-ssl-certificates.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/ot-deploy/create-ssl-certificates.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/ot-deploy/create-ssl-certificates.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/ot-deploy/activate-deploy-sensor.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/ot-deploy/activate-deploy-sensor.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/ot-deploy/activate-deploy-sensor.md
# Inserted chunk 3 of ./azure-docs/articles/defender-for-iot/organizations/ot-deploy/activate-deploy-sensor.md
# Inserted chunk 4 of ./azure-docs/articles/defender-for-iot/organizations/ot-deploy/activate-deploy-sensor.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/ot-deploy/ot-deploy-path.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/ot-deploy/ot-deploy-path.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/ot-deploy/ot-deploy-path.md
# Inserted chunk 3 of ./azure-docs/articles/defender-for-iot/organizations/ot-deploy/ot-deploy-path.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/ot-deploy/air-gapped-deploy.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/ot-deploy/air-gapped-deploy.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/ot-deploy/air-gapped-deploy.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/appliance-catalog/neousys-nuvo-5006lp.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/appliance-catalog/neousys-nuvo-5006lp.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/appliance-catalog/ys-techsystems-ys-fit2.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/appliance-catalog/ys-techsystems-ys-fit2.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/appliance-catalog/virtual-sensor-hyper-v-gen-1.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/appliance-catalog/virtual-sensor-hyper-v-gen-1.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/appliance-catalog/hpe-proliant-dl20-legacy.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/appliance-catalog/hpe-proliant-dl20-legacy.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/appliance-catalog/virtual-management-hyper-v.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/appliance-catalog/virtual-management-hyper-v.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/appliance-catalog/hpe-proliant-dl20-gen-11-nhp-2lff.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/appliance-catalog/dell-poweredge-r350-e1800.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/appliance-catalog/dell-poweredge-r350-e1800.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/appliance-catalog/dell-poweredge-r350-e1800.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/appliance-catalog/hpe-proliant-dl360.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/appliance-catalog/hpe-proliant-dl360.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/appliance-catalog/hpe-proliant-dl360.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/appliance-catalog/hpe-edgeline-el300.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/appliance-catalog/hpe-edgeline-el300.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/appliance-catalog/dell-edge-5200.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/appliance-catalog/virtual-sensor-hyper-v.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/appliance-catalog/virtual-sensor-hyper-v.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/appliance-catalog/hpe-proliant-dl20-plus-smb.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/appliance-catalog/hpe-proliant-dl20-plus-smb.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/appliance-catalog/hpe-proliant-dl20-plus-smb.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/appliance-catalog/dell-xe4-sff.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/appliance-catalog/dell-xe4-sff.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/appliance-catalog/dell-xe4-sff.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/appliance-catalog/hpe-proliant-dl20-plus-enterprise.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/appliance-catalog/hpe-proliant-dl20-plus-enterprise.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/appliance-catalog/hpe-proliant-dl20-plus-enterprise.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/appliance-catalog/hpe-proliant-dl20-gen-11.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/appliance-catalog/hpe-proliant-dl20-gen-11.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/appliance-catalog/hpe-proliant-dl20-smb-legacy.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/appliance-catalog/hpe-proliant-dl20-smb-legacy.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/appliance-catalog/dell-poweredge-r340-xl-legacy.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/appliance-catalog/dell-poweredge-r340-xl-legacy.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/appliance-catalog/dell-poweredge-r340-xl-legacy.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/appliance-catalog/virtual-management-vmware.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/appliance-catalog/virtual-sensor-vmware.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/includes/self-signed-certificate.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/includes/troubleshoot-ssl.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/includes/root-of-trust.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/includes/caution-manual-configurations.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/includes/ilo-remote-install-hpe.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/includes/on-premises-management-deprecation.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/includes/active-monitoring-protocols.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/includes/devices-inventoried.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/includes/validate-traffic-mirroring.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/integrations/on-premises-sentinel.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/integrations/service-now-legacy.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/integrations/service-now-legacy.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/integrations/service-now-legacy.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/integrations/netwitness.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/integrations/arcsight.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/integrations/logrhythm.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/legacy-central-management/legacy-air-gapped-deploy.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/legacy-central-management/legacy-air-gapped-deploy.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/legacy-central-management/prepare-management-appliance.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/legacy-central-management/prepare-management-appliance.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/legacy-central-management/how-to-manage-sensors-from-the-on-premises-management-console.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/legacy-central-management/how-to-manage-sensors-from-the-on-premises-management-console.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/legacy-central-management/how-to-manage-sensors-from-the-on-premises-management-console.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/legacy-central-management/back-up-sensors-from-management.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/legacy-central-management/back-up-sensors-from-management.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/legacy-central-management/sites-and-zones-on-premises.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/legacy-central-management/sites-and-zones-on-premises.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/legacy-central-management/sites-and-zones-on-premises.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/legacy-central-management/back-up-restore-management.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/legacy-central-management/back-up-restore-management.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/legacy-central-management/how-to-manage-the-on-premises-management-console.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/legacy-central-management/how-to-manage-the-on-premises-management-console.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/legacy-central-management/how-to-manage-the-on-premises-management-console.md
# Inserted chunk 3 of ./azure-docs/articles/defender-for-iot/organizations/legacy-central-management/how-to-manage-the-on-premises-management-console.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/legacy-central-management/how-to-work-with-alerts-on-premises-management-console.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/legacy-central-management/how-to-work-with-alerts-on-premises-management-console.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/legacy-central-management/how-to-work-with-alerts-on-premises-management-console.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/legacy-central-management/how-to-troubleshoot-on-premises-management-console.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/legacy-central-management/how-to-troubleshoot-on-premises-management-console.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/legacy-central-management/manage-users-on-premises-management-console.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/legacy-central-management/manage-users-on-premises-management-console.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/legacy-central-management/manage-users-on-premises-management-console.md
# Inserted chunk 3 of ./azure-docs/articles/defender-for-iot/organizations/legacy-central-management/manage-users-on-premises-management-console.md
# Inserted chunk 4 of ./azure-docs/articles/defender-for-iot/organizations/legacy-central-management/manage-users-on-premises-management-console.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/legacy-central-management/how-to-set-up-high-availability.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/legacy-central-management/how-to-set-up-high-availability.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/legacy-central-management/how-to-set-up-high-availability.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/legacy-central-management/activate-deploy-management.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/legacy-central-management/activate-deploy-management.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/legacy-central-management/connect-sensors-to-management.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/legacy-central-management/connect-sensors-to-management.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/legacy-central-management/how-to-investigate-all-enterprise-sensor-detections-in-a-device-inventory.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/legacy-central-management/how-to-investigate-all-enterprise-sensor-detections-in-a-device-inventory.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/legacy-central-management/how-to-investigate-all-enterprise-sensor-detections-in-a-device-inventory.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/legacy-central-management/install-software-on-premises-management-console.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/legacy-central-management/install-software-on-premises-management-console.md
# Inserted chunk 2 of ./azure-docs/articles/defender-for-iot/organizations/legacy-central-management/install-software-on-premises-management-console.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/traffic-mirroring/configure-mirror-rspan.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/traffic-mirroring/configure-mirror-span.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/traffic-mirroring/configure-mirror-span.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/traffic-mirroring/configure-mirror-hyper-v.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/traffic-mirroring/configure-mirror-hyper-v.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/traffic-mirroring/configure-mirror-esxi.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/traffic-mirroring/configure-mirror-erspan.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/traffic-mirroring/traffic-mirroring-overview.md
# Inserted chunk 0 of ./azure-docs/articles/defender-for-iot/organizations/api/sensor-alert-apis.md
# Inserted chunk 1 of ./azure-docs/articles/defender-for-iot/organizations/api/sensor-alert-apis.md
# ...
# Inserted chunk 1 of ./azure-docs/articles/advisor/advisor-operational-excellence-recommendations.md
# Inserted chunk 2 of ./azure-docs/articles/advisor/advisor-operational-excellence-recommendations.md
# Inserted chunk 0 of ./azure-docs/articles/advisor/resource-graph-samples.md
# Inserted chunk 0 of ./azure-docs/articles/advisor/advisor-recommendations-digest.md
# Inserted chunk 0 of ./azure-docs/articles/advisor/advisor-reference-cost-recommendations.md
# Inserted chunk 1 of ./azure-docs/articles/advisor/advisor-reference-cost-recommendations.md
# Inserted chunk 2 of ./azure-docs/articles/advisor/advisor-reference-cost-recommendations.md
# Inserted chunk 3 of ./azure-docs/articles/advisor/advisor-reference-cost-recommendations.md
# Inserted chunk 4 of ./azure-docs/articles/advisor/advisor-reference-cost-recommendations.md
# Inserted chunk 5 of ./azure-docs/articles/advisor/advisor-reference-cost-recommendations.md
# Inserted chunk 6 of ./azure-docs/articles/advisor/advisor-reference-cost-recommendations.md
# Inserted chunk 7 of ./azure-docs/articles/advisor/advisor-reference-cost-recommendations.md
# Inserted chunk 8 of ./azure-docs/articles/advisor/advisor-reference-cost-recommendations.md
# Inserted chunk 9 of ./azure-docs/articles/advisor/advisor-reference-cost-recommendations.md
# Inserted chunk 10 of ./azure-docs/articles/advisor/advisor-reference-cost-recommendations.md
# Inserted chunk 11 of ./azure-docs/articles/advisor/advisor-reference-cost-recommendations.md
# Inserted chunk 0 of ./azure-docs/articles/advisor/view-recommendations.md
# Inserted chunk 1 of ./azure-docs/articles/advisor/view-recommendations.md
# Inserted chunk 0 of ./azure-docs/articles/advisor/advisor-alerts-bicep.md
# Inserted chunk 1 of ./azure-docs/articles/advisor/advisor-alerts-bicep.md
# Inserted chunk 0 of ./azure-docs/articles/advisor/advisor-performance-recommendations.md
# Inserted chunk 1 of ./azure-docs/articles/advisor/advisor-performance-recommendations.md
# Inserted chunk 2 of ./azure-docs/articles/advisor/advisor-performance-recommendations.md
# Inserted chunk 3 of ./azure-docs/articles/advisor/advisor-performance-recommendations.md
# Inserted chunk 4 of ./azure-docs/articles/advisor/advisor-performance-recommendations.md
# Inserted chunk 5 of ./azure-docs/articles/advisor/advisor-performance-recommendations.md
# Inserted chunk 0 of ./azure-docs/articles/advisor/includes/azure-advisor.md
# Inserted chunk 1 of ./azure-docs/articles/advisor/includes/azure-advisor.md
# Inserted chunk 0 of ./azure-docs/articles/communication-services/overview.md
# Inserted chunk 1 of ./azure-docs/articles/communication-services/overview.md
# Inserted chunk 2 of ./azure-docs/articles/communication-services/overview.md
# Inserted chunk 0 of ./azure-docs/articles/communication-services/support.md
# Inserted chunk 0 of ./azure-docs/articles/communication-services/whats-new.md
# Inserted chunk 1 of ./azure-docs/articles/communication-services/whats-new.md
# Inserted chunk 2 of ./azure-docs/articles/communication-services/whats-new.md
# Inserted chunk 0 of ./azure-docs/articles/communication-services/resources/learn-modules.md
# Inserted chunk 0 of ./azure-docs/articles/communication-services/resources/troubleshooting/voice-video-calling/audio-issues/delay-issue.md
# Inserted chunk 0 of ./azure-docs/articles/communication-services/resources/troubleshooting/voice-video-calling/audio-issues/microphone-issue.md
# Inserted chunk 0 of ./azure-docs/articles/communication-services/resources/troubleshooting/voice-video-calling/audio-issues/overview.md
# Inserted chunk 0 of ./azure-docs/articles/communication-services/resources/troubleshooting/voice-video-calling/audio-issues/echo-issue.md
# Inserted chunk 0 of ./azure-docs/articles/communication-services/resources/troubleshooting/voice-video-calling/audio-issues/poor-quality.md
# Inserted chunk 0 of ./azure-docs/articles/communication-services/resources/troubleshooting/voice-video-calling/audio-issues/network-issue.md
# Inserted chunk 0 of ./azure-docs/articles/communication-services/resources/troubleshooting/voice-video-calling/audio-issues/microphone-permission.md
# Inserted chunk 0 of ./azure-docs/articles/communication-services/resources/troubleshooting/voice-video-calling/audio-issues/speaker-issue.md
# Inserted chunk 0 of ./azure-docs/articles/communication-services/resources/troubleshooting/voice-video-calling/audio-issues/incoming-audio-low-volume.md
# Inserted chunk 0 of ./azure-docs/articles/communication-services/resources/troubleshooting/voice-video-calling/references/how-to-collect-client-logs.md
# Inserted chunk 0 of ./azure-docs/articles/communication-services/resources/troubleshooting/voice-video-calling/references/how-to-collect-windows-audio-event-log.md
# Inserted chunk 0 of ./azure-docs/articles/communication-services/resources/troubleshooting/voice-video-calling/references/how-to-collect-browser-verbose-log.md
# Inserted chunk 0 of ./azure-docs/articles/communication-services/resources/troubleshooting/voice-video-calling/references/how-to-collect-diagnostic-audio-recordings.md
# Inserted chunk 0 of ./azure-docs/articles/communication-services/resources/troubleshooting/voice-video-calling/references/ufd/screenshare-recording-disabled.md
# Inserted chunk 0 of ./azure-docs/articles/communication-services/resources/troubleshooting/voice-video-calling/references/ufd/camera-stopped-unexpectedly.md
# Inserted chunk 0 of ./azure-docs/articles/communication-services/resources/troubleshooting/voice-video-calling/references/ufd/camera-start-timed-out.md
# Inserted chunk 0 of ./azure-docs/articles/communication-services/resources/troubleshooting/voice-video-calling/references/ufd/network-relays-not-reachable.md
# Inserted chunk 0 of ./azure-docs/articles/communication-services/resources/troubleshooting/voice-video-calling/references/ufd/camera-permission-denied.md
# Inserted chunk 0 of ./azure-docs/articles/communication-services/resources/troubleshooting/voice-video-calling/references/ufd/camera-freeze.md
# Inserted chunk 0 of ./azure-docs/articles/communication-services/resources/troubleshooting/voice-video-calling/references/ufd/network-reconnect.md
# Inserted chunk 0 of ./azure-docs/articles/communication-services/resources/troubleshooting/voice-video-calling/references/ufd/microphone-permission-denied.md
# Inserted chunk 0 of ./azure-docs/articles/communication-services/resources/troubleshooting/voice-video-calling/references/ufd/network-send-quality.md
# Inserted chunk 0 of ./azure-docs/articles/communication-services/resources/troubleshooting/voice-video-calling/references/ufd/capturer-start-failed.md
# Inserted chunk 0 of ./azure-docs/articles/communication-services/resources/troubleshooting/voice-video-calling/references/ufd/microphone-mute-unexpectedly.md
# Inserted chunk 0 of ./azure-docs/articles/communication-services/resources/troubleshooting/voice-video-calling/references/ufd/no-network.md
# Inserted chunk 0 of ./azure-docs/articles/communication-services/resources/troubleshooting/voice-video-calling/references/ufd/no-microphone-devices-enumerated.md
# Inserted chunk 0 of ./azure-docs/articles/communication-services/resources/troubleshooting/voice-video-calling/references/ufd/no-speaker-devices-enumerated.md
# Inserted chunk 0 of ./azure-docs/articles/communication-services/resources/troubleshooting/voice-video-calling/references/ufd/capturer-stopped-unexpectedly.md
# Inserted chunk 0 of ./azure-docs/articles/communication-services/resources/troubleshooting/voice-video-calling/references/ufd/speaking-while-microphone-is-muted.md
# Inserted chunk 0 of ./azure-docs/articles/communication-services/resources/troubleshooting/voice-video-calling/references/ufd/microphone-not-functioning.md
# Inserted chunk 0 of ./azure-docs/articles/communication-services/resources/troubleshooting/voice-video-calling/references/ufd/network-receive-quality.md
# Inserted chunk 0 of ./azure-docs/articles/communication-services/resources/troubleshooting/voice-video-calling/references/ufd/camera-start-failed.md
# Inserted chunk 0 of ./azure-docs/articles/communication-services/resources/troubleshooting/voice-video-calling/general-troubleshooting-strategies/overview.md
# Inserted chunk 1 of ./azure-docs/articles/communication-services/resources/troubleshooting/voice-video-calling/general-troubleshooting-strategies/overview.md
# Inserted chunk 0 of ./azure-docs/articles/communication-services/resources/troubleshooting/voice-video-calling/general-troubleshooting-strategies/understanding-error-codes.md
# Inserted chunk 1 of ./azure-docs/articles/communication-services/resources/troubleshooting/voice-video-calling/general-troubleshooting-strategies/understanding-error-codes.md
# Inserted chunk 2 of ./azure-docs/articles/communication-services/resources/troubleshooting/voice-video-calling/general-troubleshooting-strategies/understanding-error-codes.md
# Inserted chunk 3 of ./azure-docs/articles/communication-services/resources/troubleshooting/voice-video-calling/general-troubleshooting-strategies/understanding-error-codes.md
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[9], line 64
#      62 if __name__ == "__main__":
#      63     articles_dir = "./azure-docs/articles"
# ---> 64     process_directory(articles_dir)
#
# Cell In[9], line 59, in process_directory(directory_path)
#      57 if file.endswith('.md'):  # Adjust the file type if needed
#      58     file_path = os.path.join(root, file)
# ---> 59     process_file(file_path, doc_id)
#      60     doc_id += 1
#
# Cell In[9], line 41, in process_file(file_path, doc_id)
#      38 chunks = [content[i:i + 4000] for i in range(0, len(content), 4000)]
#      40 for idx, chunk in enumerate(chunks):
# ---> 41     embedding = generate_embeddings(chunk)
#      42     document = {
#      43         "id": str(ObjectId()),  # Unique ID for MongoDB document
#      44         "title": os.path.basename(file_path),
#    (...)
#      48         "chunk_id": idx
#      49     }
#      50     collection.insert_one(document)
#
# Cell In[9], line 27, in generate_embeddings(text)
#      18     '''
#      19     Generate embeddings from a string of text.
#      20     This will be used to vectorize data and user input for interactions with Azure OpenAI.
#      21     '''
#      23 #     response = AOAI_client.embeddings.create(
#      24 #     input = "The name of the person is surya. he has various skills in azure, openai, machine learning.",
#      25 #     model= "text-embedding-ada-002"
#      26 # )
# ---> 27     response = AOAI_client.embeddings.create(input=text, model="text-embedding-ada-002")
#      28     response = response.model_dump()
#      29     embeddings = response['data'][0]['embedding']
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/openai/resources/embeddings.py:114, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     108         embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     109             base64.b64decode(data), dtype="float32"
#     110         ).tolist()
#     112     return obj
# --> 114 return self._post(
#     115     "/embeddings",
#     116     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     117     options=make_request_options(
#     118         extra_headers=extra_headers,
#     119         extra_query=extra_query,
#     120         extra_body=extra_body,
#     121         timeout=timeout,
#     122         post_parser=parser,
#     123     ),
#     124     cast_to=CreateEmbeddingResponse,
#     125 )
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/openai/_base_client.py:1240, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1226 def post(
#    1227     self,
#    1228     path: str,
#    (...)
#    1235     stream_cls: type[_StreamT] | None = None,
#    1236 ) -> ResponseT | _StreamT:
#    1237     opts = FinalRequestOptions.construct(
#    1238         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1239     )
# -> 1240     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/openai/_base_client.py:921, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     912 def request(
#     913     self,
#     914     cast_to: Type[ResponseT],
#    (...)
#     919     stream_cls: type[_StreamT] | None = None,
#     920 ) -> ResponseT | _StreamT:
# --> 921     return self._request(
#     922         cast_to=cast_to,
#     923         options=options,
#     924         stream=stream,
#     925         stream_cls=stream_cls,
#     926         remaining_retries=remaining_retries,
#     927     )
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/openai/_base_client.py:1005, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1003 if retries > 0 and self._should_retry(err.response):
#    1004     err.response.close()
# -> 1005     return self._retry_request(
#    1006         options,
#    1007         cast_to,
#    1008         retries,
#    1009         err.response.headers,
#    1010         stream=stream,
#    1011         stream_cls=stream_cls,
#    1012     )
#    1014 # If the response is streamed then we need to explicitly read the response
#    1015 # to completion before attempting to access the response text.
#    1016 if not err.response.is_closed:
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/openai/_base_client.py:1053, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1049 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1050 # different thread if necessary.
#    1051 time.sleep(timeout)
# -> 1053 return self._request(
#    1054     options=options,
#    1055     cast_to=cast_to,
#    1056     remaining_retries=remaining,
#    1057     stream=stream,
#    1058     stream_cls=stream_cls,
#    1059 )
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/openai/_base_client.py:1005, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1003 if retries > 0 and self._should_retry(err.response):
#    1004     err.response.close()
# -> 1005     return self._retry_request(
#    1006         options,
#    1007         cast_to,
#    1008         retries,
#    1009         err.response.headers,
#    1010         stream=stream,
#    1011         stream_cls=stream_cls,
#    1012     )
#    1014 # If the response is streamed then we need to explicitly read the response
#    1015 # to completion before attempting to access the response text.
#    1016 if not err.response.is_closed:
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/openai/_base_client.py:1053, in SyncAPIClient._retry_request(self, options, cast_to, remaining_retries, response_headers, stream, stream_cls)
#    1049 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1050 # different thread if necessary.
#    1051 time.sleep(timeout)
# -> 1053 return self._request(
#    1054     options=options,
#    1055     cast_to=cast_to,
#    1056     remaining_retries=remaining,
#    1057     stream=stream,
#    1058     stream_cls=stream_cls,
#    1059 )
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/openai/_base_client.py:1020, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1017         err.response.read()
#    1019     log.debug("Re-raising status error")
# -> 1020     raise self._make_status_error_from_response(err.response) from None
#    1022 return self._process_response(
#    1023     cast_to=cast_to,
#    1024     options=options,
#    (...)
#    1027     stream_cls=stream_cls,
#    1028 )
#
# RateLimitError: Error code: 429 - {'error': {'code': 429, 'message': 'The event daily request rate of 5000 calls to has been exceeded. Requests are disabled until UTC midnight.'}}

# %%
db.command({
  'createIndexes': 'azure_collection',
  'indexes': [
    {
      'name': 'VectorSearchIndex',
      'key': {
        "c_vector": "cosmosSearch"
      },
      'cosmosSearchOptions': {
        'kind': 'vector-ivf',
        'numLists': 1,
        'similarity': 'COS',
        'dimensions': 1536
      }
    }
  ]
})
# Out:
# {'raw': {'defaultShard': {'numIndexesBefore': 1,
#    'numIndexesAfter': 2,
#    'createdCollectionAutomatically': False,
#    'ok': 1}},
#  'ok': 1}
